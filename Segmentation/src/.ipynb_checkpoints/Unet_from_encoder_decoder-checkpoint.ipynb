# %% [markdown]
# # Unet - Constructed from the main CNN encoder and Decoder
#
# This notebook shows how to use the CNN encoder and decoder network, glueing them
# together such that an Unet architecture emerges

# %%
import sys
sys.path.append('../../Shared_Resources/Shared_Scripts')
sys.path.append('./utils')


from utils_unet_from_encoder_decoder import UNet
from utils_dataset_handling import *
from utils_segmentation_training import *
from utils_save_and_load_model import *

# %% [markdown]
# ## Download the data set

# %%
data_save_dir = '../../Shared_Resources/Shared_Data/'

# %%
# Oxford IIIT Pets Segmentation dataset loaded via torchvision.
pets_path_train = os.path.join(data_save_dir, 'OxfordPets', 'train')
pets_path_test = os.path.join(data_save_dir, 'OxfordPets', 'test')

# %%
target_types = 'segmentation'
pets_train_orig = torchvision.datasets.OxfordIIITPet(root=pets_path_train, split="trainval", 
                                                target_types=target_types, download=True)
pets_test_orig = torchvision.datasets.OxfordIIITPet(root=pets_path_test, split="test", 
                                                target_types=target_types, download=True)

# %% [markdown]
# ## Preprocess the data

# %%
image_size = 32

# %%
common_transform = T.Compose([
        ToDevice(get_device()),
        T.Resize((image_size,image_size), interpolation=T.InterpolationMode.NEAREST),
        # Random Horizontal Flip as data augmentation.
        T.RandomHorizontalFlip(p=0.5),
    ])

post_transform = T.Compose([
        # Color Jitter as data augmentation.
        T.ColorJitter(contrast=0.3),
    ])

# %%
transform_dict = args_to_dict(
    pre_transform=T.ToTensor(),
    pre_target_transform=T.ToTensor(),
    common_transform=common_transform,
    post_transform=post_transform,
    post_target_transform=T.Compose([
        T.Lambda(tensor_trimap),
    ]),
)

# %%
# Create the train and test instances of the data loader for the
# Oxford IIIT Pets dataset with random augmentations applied.
# The images are resized to 128x128 squares, so the aspect ratio
# will be chaged. We use the nearest neighbour resizing algorithm
# to avoid disturbing the pixel values in the provided segmentation
# mask.
pets_train = OxfordIIITPetsAugmented(
    root=pets_path_train,
    split="trainval",
    target_types="segmentation",
    download=False,
    **transform_dict,
)
pets_test = OxfordIIITPetsAugmented(
    root=pets_path_test,
    split="test",
    target_types="segmentation",
    download=False,
    **transform_dict,
)

pets_train_loader = torch.utils.data.DataLoader(
    pets_train,
    batch_size=12,
    shuffle=True,
)
pets_test_loader = torch.utils.data.DataLoader(
    pets_test,
    batch_size=6,
    shuffle=True,
)

# %%
(train_pets_inputs, train_pets_targets) = next(iter(pets_train_loader))
(test_pets_inputs, test_pets_targets) = next(iter(pets_test_loader))
train_pets_inputs.shape, train_pets_targets.shape
# Out:
# (torch.Size([12, 3, 32, 32]), torch.Size([12, 1, 32, 32]))

# %%
# Let's inspect some of the images.
pets_input_grid = torchvision.utils.make_grid(train_pets_inputs, nrow=8)
t2img(pets_input_grid)
# Out:
# <PIL.Image.Image image mode=RGB size=274x70>

# %%
# Let's inspect the segmentation masks corresponding to the images above.
#
# When plotting the segmentation mask, we want to convert the tensor
# into a float tensor with values in the range [0.0 to 1.0]. However, the
# mask tensor has the values (0, 1, 2), so we divide by 2.0 to normalize.
pets_targets_grid = torchvision.utils.make_grid(train_pets_targets / 2.0, nrow=8)
t2img(pets_targets_grid)
# Out:
# <PIL.Image.Image image mode=RGB size=274x70>

# %% [markdown]
# ### Training functions

# %%
# Define training loop. This will train the model for multiple epochs.
#
# epochs: A tuple containing the start epoch (inclusive) and end epoch (exclusive).
#         The model is trained for [epoch[0] .. epoch[1]) epochs.
#
def train_loop(model, loader, test_data, epochs, optimizer, scheduler, save_path,print_every=2):
    os.makedirs(save_path, exist_ok=True)
    test_inputs, test_targets = test_data
    epoch_i, epoch_j = epochs
    for i in range(epoch_i, epoch_j):
        epoch = i
        print(f"Epoch: {i:02d}, Learning Rate: {optimizer.param_groups[0]['lr']}")
        train_model(model, loader, optimizer)
        if i%print_every==0:
            with torch.inference_mode():
                # Display the plt in the final training epoch.
                print_test_dataset_masks(model, test_inputs, test_targets, 
                                         epoch=epoch, save_path=save_path, show_plot=(epoch == epoch_j-1))

        if scheduler is not None:
            scheduler.step()

# %% [markdown]
# ### Initialize Unet model

# %%
dimension_specification =   {0: {'width_encoder': 10, 'depth_encoder': 1, 
                                 'width_decoder': 10, 'depth_decoder': 1,'width_skip': 5},
                             1: {'width_encoder': 20, 'depth_encoder': 1, 
                                'width_decoder': 20, 'depth_decoder': 1,'width_skip': 5}
                            }

# %%
unet = UNet(in_ch=3,out_ch=3,n_decoders=1,verbose=True,pooling_mode='max',
            output_activation=None, dimension_specification = dimension_specification)
# Out:
# dimension_specification:  {0: {'width': 10, 'depth': 1, 'width_skip': 5}, 1: {'width': 20, 'depth': 1, 'width_skip': 5}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zs/rjvzt_c954d5v9kwyknv4gy00000gn/T/ipykernel_27112/3698440094.py in <module>
# ----> 1 unet = UNet(in_ch=3,out_ch=3,n_decoders=1,verbose=True,pooling_mode='max',
#       2             output_activation=None, dimension_specification = dimension_specification)
#
# ~/Documents/projects/ConvNetComet/Shared_Resources/Shared_Scripts/utils_unet_from_encoder_decoder.py in __init__(self, in_ch, out_ch, n_decoders, verbose, pooling_mode, output_activation, dimension_specification)
#      55         self.model_type_to_dimension_specification = self.get_model_type_to_dimension_specification()
#      56
# ---> 57         self.encoder = CNNEncoder(in_ch = in_ch, dimension_specification = self.model_type_to_dimension_specification['encoder'],
#      58                                     pooling_mode=pooling_mode, verbose = verbose)
#      59         self.decoders = CNNDecoder(out_ch=out_ch,output_activation = output_activation,
#
# ~/Documents/projects/ConvNetComet/Shared_Resources/Shared_Scripts/utils_cnn_encoder_and_decoder.py in __init__(self, in_ch, dimension_specification, pooling_mode, verbose)
#     197
#     198         self.preprocessing_layer = self.get_preprocessing_layer()
# --> 199         self.down_layers, self.skip_layers = self.get_encoder_layers()
#     200
#     201     def check_if_dimension_specification_is_valid(self):
#
# ~/Documents/projects/ConvNetComet/Shared_Resources/Shared_Scripts/utils_cnn_encoder_and_decoder.py in get_encoder_layers(self)
#     232             #adding depth at that scale
#     233             for k in range(dimensions['depth']):
# --> 234                 down_layer_i.append(ResidualBlock2(dimensions['width'], kernel_size = 1))
#     235
#     236
#
# ~/Documents/projects/ConvNetComet/Shared_Resources/Shared_Scripts/utils_cnn_encoder_and_decoder.py in __init__(self, channels, kernel_size, bias)
#     389     def __init__(self, channels,kernel_size=3,bias=True):
#     390         super(ResidualBlock2, self).__init__()
# --> 391         self.conv1 = ConvLayerEqual(channels, channels, kernel_size=kernel_size, stride=1,bias=bias)#I should set bias=False, since followed by bn
#     392         self.bn1 = nn.BatchNorm2d(channels, affine=True)
#     393         self.conv2 = ConvLayerEqual(channels, channels, kernel_size=kernel_size, stride=1,bias=bias)#I should set bias=False, since followed by bn
#
# TypeError: __init__() got an unexpected keyword argument 'stride'
